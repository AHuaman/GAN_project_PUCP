# %% [markdown]
# # Probando el clusterizador de SUB-GAN con MNIST

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.datasets import mnist

# %matplotlib inline
# Out:
# C:\Users\huama\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test)=mnist.load_data()

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# Normalización
mu = x_train.mean()
sigma = x_train.std()

x_train = (x_train - mu) / sigma
x_test = (x_test - mu) / sigma

x_train.mean(), x_test.mean(), x_train.std(), x_test.std()
# Out:
# (-3.064638490070051e-17,
#  0.0060177948928480576,
#  0.9999999999999998,
#  1.0077000453879372)

# %% [markdown]
# ## Realizamos el cálculo de la matriz **C** de correlaciones

# %%
nb=20
X=(x_train[0:nb,:,:].reshape([nb,28*28])).T #Revisar si 'T' es lo correcto
X.shape
# Out:
# (20, 784)

# %%
# Dado que hubieron graves problemas con la dimensionalidad de la matriz de la muestra de 2 imágenes MNIST,
# se decide utilizar una matriz artifical a modo de ejemplo para comprobar que el cluster funciona. Cuando
# la mtriz es muy esparsa, el solver no brinda una respuesta:
X=np.array(np.random.randn(nb*50)*8+np.random.randint(0,10,nb*50)).reshape([nb,50])
X.shape
# Out:
# (20, 50)

# %%
X
# Out:
# array([[ 9.74044338e+00,  2.59851633e+00,  1.12792070e+01,
#         -1.10730415e+01,  1.27890309e+01,  4.08391335e+00,
#          5.77482140e+00,  4.79634081e+00,  5.76928919e+00,
#         -5.54390562e+00, -3.00158380e+00,  7.17932083e+00,
#          1.24559443e+01,  5.73070701e+00,  2.76226445e+01,
#         -3.80647984e+00,  2.21986247e+01,  5.95596864e+00,
#          1.34884856e+01,  1.68153001e-01,  2.43159908e+01,
#          1.47568718e+01,  2.59991800e+01,  9.20027751e+00,
#          1.80110803e+01,  2.17328260e+00, -1.23692023e+01,
#         -1.16620397e+01, -7.07339361e+00, -1.28942570e+00,
#          2.43197767e+00, -2.96792240e+00,  5.70844168e+00,
#          1.74825978e+01, -2.78499868e+00,  2.79016665e+00,
#          4.91583766e+00,  1.19014373e+01,  6.05342882e+00,
#          4.50046414e+00, -6.02667841e+00,  7.07468016e+00,
#         -1.55138532e+00,  9.83561090e+00, -5.55534217e+00,
#          1.06734336e+01,  1.26630138e-01,  8.44606937e+00,
#          1.52214432e+01,  2.62966798e+00],
#        [ 2.81752464e+01,  5.26968909e+00,  1.57852882e+01,
#         -4.49398372e+00, -3.90493647e+00,  8.01721963e+00,
#          2.06520155e+00, -7.30735997e+00,  8.78557481e+00,
#          7.17506016e+00, -2.52203981e+00,  5.34603131e+00,
#          3.22313594e+01,  6.18417057e+00,  1.12207827e+01,
#         -1.93486137e+00,  1.59401381e+01, -9.22284032e+00,
#         -6.89303305e+00,  4.58304670e+00,  4.29064697e+00,
#         -6.06695782e-02,  2.98229697e+00,  4.91541060e+00,
#          1.48467176e+01,  1.16799293e+01,  1.22208817e+01,
#          2.91228883e+00,  8.78036678e+00,  1.38680184e+01,
#          1.48571076e+01,  1.46720934e+01,  1.06587215e+01,
#          6.03472092e+00, -7.34094239e+00, -3.54601403e+00,
#          5.25923783e+00,  2.82080375e+00,  1.93956350e+01,
#          1.27671667e+01, -1.12566612e+00,  1.07959069e+01,
#          7.18614459e+00, -5.98459426e+00, -6.18794373e+00,
#          3.98309417e-01,  7.63830260e+00,  1.90568105e+01,
#          5.83817981e+00, -5.28880280e-01],
#        [ 1.30644567e+01, -2.86613256e+00,  5.26772666e+00,
#         -3.52538134e+00,  1.23243377e+01,  5.11153928e+00,
#          1.56003774e+00,  1.40049398e+00, -1.18997294e-01,
#         -6.81039718e-01,  1.11118780e+01,  1.00375748e+01,
#          3.69641352e+00,  6.13657194e+00, -1.23229669e+00,
#          6.24570513e+00, -1.00054455e+01,  8.89775078e+00,
#         -7.04257549e+00, -1.68429774e+00,  5.45334335e+00,
#          1.29259004e+01, -6.04210603e+00,  6.10330677e+00,
#          1.67318487e+01,  1.90667798e+01, -4.39652598e+00,
#          3.30052361e+00, -9.03198860e+00,  1.37749402e+01,
#          1.19675996e+01,  8.11945476e+00, -2.30904497e+01,
#         -1.06050421e+01,  9.49868145e+00, -5.01279070e+00,
#          3.22933879e+00,  1.26689770e+01,  4.39300548e+00,
#          3.28902654e-01,  1.72222285e+01,  1.57082181e+01,
#          1.02633124e+01,  8.10687002e+00, -4.06359631e-01,
#          3.41933622e+00,  1.04942855e+01,  1.09825981e+01,
#          3.29948164e+00,  2.18211361e+00],
#        [ 2.15608774e+00, -6.94816564e-01,  1.34440561e+00,
#         -9.40755003e+00,  8.23902207e+00, -7.58167609e+00,
#          1.21880320e+01, -9.84761200e+00,  1.09625624e+01,
#         -2.05929567e-01,  1.85838813e+01,  2.55818028e-02,
#          5.66090784e+00,  5.11994128e+00,  2.57082901e+00,
#         -5.10719303e+00,  4.33620219e+00,  2.32057985e+00,
#          1.85769912e+01,  3.66007039e+00,  3.54632880e+00,
#          5.03732627e+00,  5.75148235e+00,  1.62029467e+01,
#         -4.89638555e-02,  1.01015652e+00,  6.89633591e-01,
#          9.11932392e+00,  2.38129636e+00,  1.88967716e-01,
#          2.63482643e+01,  6.39208499e+00, -2.04809186e+00,
#          9.67834085e+00,  1.24829826e+00, -9.44318933e+00,
#         -4.68241915e+00,  9.42208418e+00,  3.65220849e+00,
#         -5.70574037e-01,  7.89726434e+00, -9.13043929e-01,
#          1.17158134e+01, -1.46272700e+00, -4.92024395e+00,
#          1.55192205e+00, -7.40287667e+00,  2.38308316e+00,
#          4.05923180e+00,  7.86914568e-01],
#        [-4.29563130e+00,  1.04211414e+01,  1.10426630e+01,
#         -4.06799049e+00,  1.00553549e+01, -6.36150108e-01,
#          2.17466625e+01, -5.99065144e-01, -7.14513567e+00,
#         -4.84742197e+00, -1.47348489e+00, -5.68303942e+00,
#          9.42697012e+00, -5.67530347e+00,  1.02938801e+01,
#         -6.54224271e+00,  3.47101499e+00,  1.75674025e+01,
#          4.20681934e+00, -8.56006149e-01,  1.28862277e+01,
#          1.60626795e+00,  8.96458778e+00,  2.19081185e+00,
#          9.41166947e+00,  1.29256048e+01,  4.24845310e+00,
#         -2.01013028e-01,  2.72038047e+00,  1.20014475e+01,
#          1.43386311e+01,  5.47054806e+00,  7.58810769e+00,
#          5.12142330e+00,  1.27842128e+01,  2.30919625e+00,
#          8.42165025e+00,  1.37033959e+01,  1.27021679e+01,
#          1.46056200e+01,  1.96731128e+01,  4.61918340e+00,
#          2.42619121e+00,  1.17478295e+00,  1.11828082e+01,
#          1.32599830e+01, -2.04731507e-01,  1.59869224e+01,
#          9.05418094e+00, -1.26883069e+00],
#        [ 1.45462924e+01,  1.48550072e+01,  1.95603786e+01,
#          3.95728874e+00, -6.67747857e+00,  5.21141835e+00,
#         -7.08175882e+00,  2.33274215e+01,  4.76042927e+00,
#          5.55419901e+00,  1.29524306e+01,  3.39590105e-01,
#         -4.28968639e+00,  6.30866129e+00,  1.31300403e-01,
#         -3.65512291e+00, -4.06849615e+00, -2.70163728e+00,
#         -2.71049326e+01, -1.48641415e+00,  1.46222742e+01,
#          2.73236225e+00, -1.83878833e+00,  1.33031179e+01,
#          5.07354319e+00,  5.49293749e-01, -1.91689873e+00,
#          3.60338482e+00, -1.37655058e+00, -1.37731849e+01,
#         -1.35981126e+01,  8.10831691e+00,  3.03468287e+00,
#         -1.38972959e+01,  1.05327196e+01,  1.42159690e+01,
#          8.89835417e+00,  6.00080945e-01, -3.84524435e+00,
#         -6.54826926e+00,  1.19215324e+01,  2.76424012e+00,
#          1.07619426e+01, -3.01042642e+00,  1.94006903e+00,
#         -1.25549534e+01,  1.58971687e+01,  4.99897496e+00,
#          1.18276506e+00,  2.40035707e+00],
#        [ 8.78983265e-01,  4.36979690e+00,  6.32294096e+00,
#         -3.37492370e+00,  6.61708122e+00,  5.21907816e+00,
#          1.63530650e+01,  1.67390885e+01,  1.47377841e+01,
#          9.99912034e+00, -3.01214092e+00, -3.39714747e+00,
#         -3.31034879e+00,  1.18647732e+01, -8.32482987e-01,
#          1.08333458e+01, -2.21111118e+00,  8.54459857e+00,
#          2.26429315e+01,  5.67612045e+00,  1.93430094e+01,
#          1.20527631e+00,  6.54889043e+00, -8.66125136e-01,
#          1.10337795e+01,  1.37053286e+00,  9.90986223e+00,
#          4.23811349e+00,  1.03313260e+01,  1.04266869e+01,
#          1.47600768e+01, -2.39912360e+00,  5.27718067e+00,
#         -2.49239842e+00, -1.88312782e+00,  6.08825433e+00,
#          9.45680278e+00,  4.90312823e+00, -6.49005779e-01,
#         -5.23045222e+00,  4.63028829e+00, -1.05063970e+01,
#         -5.47249054e-01, -3.77288547e+00,  6.24894373e+00,
#          2.40991573e+01, -3.16606148e+00,  6.95113211e+00,
#         -2.94753320e+00,  1.96679441e+00],
#        [-3.22200425e+00,  5.73996454e+00, -1.19579152e+00,
#          6.07548026e+00, -2.09083980e+00,  3.29802287e+00,
#          3.67765145e+00,  1.23813144e+00,  1.66165879e+01,
#         -1.28429189e+01,  1.12918507e+01, -4.14399458e+00,
#          7.77124392e+00,  3.06294523e+01,  2.14202752e+01,
#         -9.98135553e+00, -2.86053572e+00,  1.00826033e+01,
#         -3.14124890e+00,  1.07591155e+01,  5.46388972e+00,
#          1.67679843e+01,  1.80491483e+01,  6.39421795e-01,
#         -1.50137683e+01,  1.56659351e+01,  5.62492414e+00,
#         -2.72987383e+00, -3.27409048e+00,  1.18474095e+01,
#         -5.34254242e+00,  1.34277246e+00,  7.29280291e+00,
#          3.18054266e+00,  1.65397132e+01, -2.91661718e+00,
#          3.38839506e+00,  4.82040650e+00,  5.05446575e+00,
#          4.70146079e+00,  2.10344705e+01,  8.80875064e+00,
#          9.27752647e+00,  1.21310403e+01, -2.73251077e+00,
#          3.00607117e+00,  2.52698454e-01,  1.86286662e+00,
#          1.70040973e+00,  8.82616783e+00],
#        [ 8.84102741e+00,  1.85428205e+01, -1.27978143e+01,
#          8.64679461e-02,  6.40989496e+00,  2.51409230e+01,
#          7.35118717e+00, -7.62503034e-01, -5.55203773e+00,
#          8.25673127e+00,  7.49629141e+00,  7.08367193e+00,
#         -1.71246204e+01,  1.54488251e+01,  1.36407834e+01,
#         -5.49863894e+00, -6.91197141e-01, -1.12647298e+00,
#         -4.31712956e+00,  2.33593818e+00,  1.61574114e+00,
#          4.29895176e+00,  9.99130524e+00,  8.10504738e+00,
#         -2.24072117e+00,  1.42751868e+01, -1.41848396e+00,
#          5.21902393e-02, -1.05811536e+01,  1.66675889e+01,
#          1.63673349e-01, -5.41035822e+00,  2.49159617e+00,
#          1.02851528e+01,  5.08498521e+00,  4.38420971e-01,
#          1.61669350e+00,  2.37175459e+01,  5.30981656e+00,
#          8.27727104e+00, -1.18409819e+01, -1.57611008e+00,
#          1.97506720e+01,  8.43142570e+00,  3.54711951e+00,
#          3.29832170e+00,  2.58898711e+00,  5.13925987e+00,
#         -6.68938928e+00, -4.96833458e+00],
#        [-1.05451432e+01, -1.76700643e+00, -6.86232386e-01,
#          1.45888555e+01,  1.70683177e+01,  2.01840744e+00,
#          1.24468245e+01,  6.70443540e-01,  3.13589762e+00,
#          1.23398542e+01,  3.80152557e+00,  1.81981345e+00,
#          9.67483153e+00, -8.32303468e-02,  1.30838955e+01,
#          1.28134299e+01,  6.52027081e-01,  1.11459089e+01,
#          7.51285475e+00,  2.49607718e+01,  7.07572851e+00,
#          1.31778946e+01,  2.23360193e+00,  5.27672474e+00,
#          7.86835187e+00, -8.32009571e-01, -2.55816307e+00,
#          6.58899665e+00,  1.69513696e+01, -1.18375307e+01,
#          1.64164948e+01,  7.53257584e+00,  8.92934870e+00,
#          1.70337208e+01, -9.55790707e-01,  2.81560454e+00,
#         -9.27570518e+00,  9.81050689e+00,  9.48896303e-01,
#          1.07269758e+01,  7.08346423e+00, -9.02293302e-02,
#          1.29437446e+01, -1.21552412e+01, -5.42550366e-01,
#          2.92010693e+00,  7.80041734e+00, -6.66340288e+00,
#         -4.43174318e+00,  3.30667867e+00],
#        [ 4.87361878e+00,  3.37023812e+00,  3.57343816e+00,
#         -4.35806122e-01, -1.03095528e+00,  1.89544487e+00,
#          5.69726589e+00, -5.64122724e+00,  1.13708869e+00,
#         -1.11483783e+01, -1.06528552e+01,  6.54310647e-01,
#          1.20025297e+01, -3.66376527e+00, -2.91680712e+00,
#          2.15337163e-01, -3.89048101e+00,  2.82131377e+00,
#          2.40733753e+01,  1.20459838e+01,  9.07286724e+00,
#         -3.95151724e+00,  5.10021458e+00,  1.40885726e+00,
#          9.67400556e+00, -2.12415275e+01,  1.01095526e+01,
#          2.17780170e+01,  2.07647136e+01,  9.52951325e+00,
#          1.26130156e+01,  1.68171782e+01,  1.39171246e+01,
#         -9.30034661e-01, -7.82975272e+00, -2.93240405e+00,
#          2.81099837e+00,  1.67433637e+01,  1.19828614e+01,
#         -8.55898451e+00,  1.21893748e+01, -4.27256303e+00,
#          3.18588379e+00,  1.73592193e+01,  1.07556253e+01,
#          1.64789107e+00,  1.30148769e+01,  4.05514292e+00,
#          1.81140085e+01,  1.70731363e+00],
#        [ 8.52818432e+00, -1.10237323e+00,  1.11352170e+00,
#         -1.20007926e+00, -6.02737234e+00,  2.69211313e+00,
#          1.33487274e+01,  1.98760428e+00,  4.16185032e+00,
#         -6.80687300e+00,  3.48123807e+00,  2.74040615e+00,
#          2.03738003e+01, -9.20424382e+00,  3.04878755e+00,
#          6.16354570e+00,  9.87580249e-01,  2.38932615e+00,
#         -2.06017110e+00,  8.82039605e+00,  6.84423077e+00,
#          3.82677536e+00,  3.45072989e+00,  1.60022991e+01,
#          2.37270556e+00,  6.78059763e+00,  1.01782247e+01,
#          9.22510981e+00, -1.79165530e+00,  8.74968675e+00,
#         -1.53181333e+00, -4.64376076e+00,  7.96870723e+00,
#         -4.74535276e+00,  2.24342267e-01,  2.28047791e+01,
#          6.96345254e+00, -2.64108416e+00, -1.47444025e-01,
#          1.25455031e+01, -1.02240192e+01,  2.34263618e+01,
#          7.82905065e+00,  9.46768555e+00,  5.63564695e+00,
#          7.99198233e-01, -1.62064533e+01,  1.06087233e+01,
#          5.58916637e+00,  2.65041622e+01],
#        [-1.57399208e+00,  6.39352666e+00,  1.89529304e+01,
#          1.04681587e+01, -2.74173735e-01,  2.12498142e+01,
#          2.20810318e+00,  8.83554115e+00, -3.23749465e+00,
#         -4.79052594e+00,  3.24633973e+00,  1.02955515e+01,
#          1.32200435e+01,  2.48638464e+01,  1.77698026e+01,
#          1.01369188e+01, -3.17629689e+00, -6.16145542e+00,
#         -1.95985803e+00, -3.28634984e+00,  1.00290730e+01,
#          7.47107356e-02,  1.70222933e+01,  1.20158034e+01,
#          9.76964925e+00,  1.46204965e+01,  6.31138851e+00,
#          8.58599573e+00, -2.15997009e+00,  1.06148641e+01,
#         -1.13582936e+01, -1.98809099e+00,  9.02435339e-01,
#          1.04417137e+00, -1.23467061e+01, -2.21161007e+00,
#         -3.41258917e-01, -5.39044241e-01,  7.73798709e+00,
#          1.94439281e+01,  3.49342385e+00,  1.30424259e+01,
#          1.17088637e+01,  5.80311967e+00, -9.90243533e+00,
#          1.80214444e+00,  1.90348965e+01, -1.31816729e+00,
#          2.08781139e+00,  2.10877142e+01],
#        [-1.42624336e+00,  1.97639559e+01,  1.56365905e+01,
#         -4.35918066e+00,  7.56882538e+00,  2.08406342e+01,
#          1.47695644e+01, -6.56730423e+00,  2.98971484e+00,
#          4.24341712e+00,  6.66059220e+00, -8.13754219e-01,
#          8.55858169e-02, -3.52065915e+00,  1.74199541e+01,
#          1.74649577e+01,  2.51825024e+00, -5.13673846e+00,
#          4.58487241e+00,  9.51289611e+00,  1.23822363e+01,
#         -1.95585900e+01,  3.39113813e+01, -7.65889680e+00,
#          8.26439455e+00, -1.86501757e+00,  1.21599827e+01,
#          4.43352912e+00, -1.22566986e+00,  1.27754862e+01,
#          1.13301745e+01,  3.30603998e+00,  4.68169020e+00,
#          1.95486911e+00,  1.85859666e+00,  9.39930496e+00,
#          4.46660868e+00,  1.15182738e+01,  3.03168728e+00,
#         -1.19107345e+01,  5.34340805e+00,  1.70140508e+01,
#         -1.33606355e+01, -1.23245010e+00,  6.24822179e+00,
#          2.33854461e+00, -9.40675125e+00,  8.42203020e+00,
#          8.49315732e+00, -4.89434001e+00],
#        [-3.46999348e+00, -2.81863349e+00, -3.06642190e-01,
#          6.31953569e+00,  6.56310940e+00,  6.83342343e+00,
#          1.05214294e+01, -1.14006068e+01,  1.36951222e+01,
#          9.69089929e+00,  3.19931179e+00,  1.13553727e+01,
#         -1.49511832e+01,  1.32496361e+01, -1.95150512e+01,
#          2.05465599e+01,  1.27123592e+01,  2.24317881e+01,
#          1.56623776e+01,  2.55698631e+00,  1.12867389e+00,
#          1.19550635e+00, -7.98520708e+00,  2.64866682e+00,
#         -9.15926320e+00,  4.59806061e+00, -1.50728455e+01,
#         -5.33097241e+00,  2.07122663e-01, -2.98662349e+00,
#          1.52219183e+00,  5.39327559e+00,  8.76286883e+00,
#         -1.16096491e+01,  1.20863513e+01,  3.81793338e+00,
#          1.16308614e+01,  1.50973124e+01, -5.54626588e+00,
#          1.13037815e+01,  1.22154169e+01,  1.32998845e+01,
#          8.50538849e+00,  1.83418663e+00,  1.74692910e+01,
#         -1.70210442e+00,  2.57369131e+01, -2.21098836e+00,
#          5.51390354e+00, -5.24779140e+00],
#        [ 1.00958760e+01,  1.09946656e+01,  1.53327709e+01,
#          8.64373797e+00, -9.55074233e-01,  2.53620203e+00,
#         -4.99938127e+00, -1.37446944e+01,  1.62861049e+01,
#         -3.85448171e+00, -1.11191483e+01,  8.13249265e+00,
#         -4.72227461e+00, -2.58839989e-01, -6.95422740e+00,
#         -5.48436780e+00, -6.50865054e+00,  6.77105808e+00,
#          1.81142145e+01, -4.84795568e+00,  1.34183289e+01,
#         -1.20649546e+01,  1.78428102e+01, -3.89565928e+00,
#         -7.51878349e-01, -1.36211403e+00,  3.85382962e+00,
#          6.77910339e+00,  1.76265594e+00,  8.56602881e+00,
#          1.26050610e+01,  3.53331269e+00,  1.36671673e+00,
#          7.35824655e-01,  9.62416617e-01,  9.22949653e+00,
#          9.50555491e+00,  8.80330648e+00,  1.30583513e+01,
#          2.74253306e+01,  4.58300974e+00, -3.17203063e+00,
#          1.08804770e+01, -3.52456681e+00, -8.22511780e+00,
#         -2.88322886e+00,  2.10271679e+01,  2.54683514e+00,
#         -1.94775864e+00,  1.16758772e+01],
#        [-5.63216883e+00, -1.09597705e+00,  1.11733022e+01,
#          1.03572370e+01, -2.88473630e+00,  1.32851978e+01,
#         -4.28929387e+00,  2.10906415e+00,  2.04973220e+01,
#          1.33567219e+01,  8.48661638e+00,  1.09942551e+01,
#         -1.65491709e+01,  1.02813072e+01,  2.24856011e+01,
#          9.18593228e+00,  2.33081929e+01,  1.68444135e+01,
#         -5.31048949e+00, -2.34703562e+00,  3.63505712e+00,
#          1.90316474e+01, -1.66261298e+00, -2.03172926e+00,
#          2.72646458e+00,  1.02560196e+01,  2.86674650e+00,
#         -2.50285289e+00,  1.87922017e+01,  1.70672134e+00,
#          1.12896328e+01,  1.49911236e+01, -2.37741018e+00,
#          3.90145241e+00, -1.30557864e+00,  1.35835336e+01,
#         -2.36567287e+00,  1.75650554e+01, -5.88870278e+00,
#         -6.24707105e-01,  9.32693732e+00,  8.96309956e+00,
#          7.56272114e+00,  1.93704422e+01,  2.51745457e+01,
#          1.39796206e-02,  5.78297898e+00, -6.27768003e+00,
#         -4.92387529e+00,  1.39479026e+01],
#        [-6.11523511e-01,  4.36639739e+00, -5.00971627e+00,
#         -6.13322664e-01,  6.40018498e+00, -3.27352101e+00,
#          9.03854280e-01, -2.06242920e+00,  2.94460519e+01,
#         -5.77405400e+00,  7.00846293e+00,  1.05267096e+01,
#          4.17331690e+00, -2.49219677e+00,  1.05377924e+01,
#          1.15456360e+01, -1.03132052e+01,  9.17168986e+00,
#         -9.82938952e+00,  5.70039338e+00,  3.60240451e-01,
#          2.19551047e+00, -2.31324528e+00,  9.84676306e+00,
#          1.60033365e+01,  1.84486087e+01, -7.16810146e-01,
#          1.00702289e+01,  2.90706317e+00,  1.45021904e+01,
#          7.51904849e+00,  7.04932247e+00,  5.76344951e+00,
#          4.15618642e+00,  2.39598388e+00,  1.23067583e+00,
#         -2.38885441e-01,  2.30978669e+00,  1.48606202e+01,
#         -5.33570585e+00,  6.61986119e+00,  7.33379534e+00,
#          1.67620905e+01, -8.64660353e+00,  5.80747029e+00,
#         -3.86068202e+00,  1.34130458e+01, -8.75766679e+00,
#         -1.08415318e+00,  9.92452469e+00],
#        [ 5.79883237e+00, -3.47714476e+00, -4.89809442e+00,
#          6.78667985e+00,  3.74952184e+00,  6.69059483e+00,
#         -4.36941908e+00, -6.09874495e+00, -1.16324860e+01,
#          5.72936516e+00,  4.30711437e+00,  1.53589845e+01,
#          1.04025353e+01,  4.77166734e+00, -2.89870000e+00,
#          1.25341873e+01, -2.51749897e+00,  7.83233192e+00,
#         -8.10168366e+00,  1.27289443e+01,  1.31392053e+01,
#          9.90881688e-01, -7.07141893e+00, -7.40209852e+00,
#          3.40104110e+00, -5.03908639e+00, -1.31458945e+00,
#         -5.45790125e-01,  6.97057942e+00,  6.20973370e+00,
#         -2.07700345e+00,  7.64276674e+00,  2.36313516e+00,
#          1.88207731e+01,  1.02318328e+00,  2.50529992e+00,
#          3.54963744e+00,  8.11400502e+00, -1.02447430e+00,
#          7.38338980e+00,  5.64635039e+00,  5.95708517e+00,
#          2.24919718e+01, -1.23981342e+01,  1.43779918e+01,
#         -9.30967810e-01,  2.41726451e+00,  1.62336815e+01,
#          1.22235719e+00,  1.17150237e+00],
#        [-1.91979954e+00, -2.80309594e+00,  9.40123652e+00,
#          1.62970434e+00,  8.13888055e+00,  4.84938522e-01,
#          1.87594960e+01,  7.39614523e+00, -1.15471934e+01,
#          3.34065339e+00, -6.25239280e-01,  1.40211302e+01,
#         -3.60315571e+00, -1.39045345e+01,  6.13178936e+00,
#          6.00103713e-02,  5.14416262e+00,  1.28700938e+01,
#          1.28548256e+01,  9.00024148e+00,  8.80979289e+00,
#          1.17106226e-02,  2.15125382e+01, -3.38511343e+00,
#          8.79021583e+00,  8.46265194e+00,  1.39267582e+01,
#          8.84196339e+00,  1.54036781e+01,  2.96038371e+00,
#         -8.88852510e-01,  5.04600720e+00,  9.59761284e+00,
#          8.36909795e+00, -4.66937680e+00, -1.32377771e+00,
#          1.59735441e+01,  1.50448929e+01,  1.26135814e+01,
#          7.53968841e+00, -1.31787927e+01,  9.26996254e+00,
#          1.14206806e+01, -3.09692712e+00,  4.88046715e+00,
#         -1.57413697e+01, -1.13036534e+01,  1.26319158e+01,
#         -2.74761972e+00,  3.29949664e+00]])

# %%
# Hiperparámetros:
lbd=0.01 #Lambda. Suele estar entre 0.001 y 0.01, según teoría de 'subspace clustering'
k=4 #Cantidad de subespacios a encontrar

import cvxpy as cvx #libreria para optimización convexa

# %%
# Definimos el programa convexo:
C=cvx.Variable(X.shape[1], X.shape[1]) # Matriz NxN
objective=cvx.Minimize(cvx.norm(X - X@C,2)**2 + lbd*cvx.norm(C,1))
constraint=[cvx.diag(C)==0]
problem=cvx.Problem(objective,constraint)

# %%
X.shape, C
# Out:
# ((20, 50), Variable(50, 50))

# %%
# Códigos para la correcta instalación de 'cvxpy' en Python3:
# FUENTE:   https://www.cvxpy.org/install/index.html
# Desgargar Visual Studio C++ compiler for Python. Luego correr:
# conda install -c conda-forge lapack 
# conda install -c cvxgrp cvxpy
# Además, instalar el solver 'CVXOPT' pues 'SCS' no funciona correctamente aún en Windows con Python3.
# Toma bastante tiepo pues pesa >200 MB:
# conda install -c conda-forge cvxopt
# O también se puede utilizar el solver 'MOSEK':
# conda install -c mosek mosek

# %%
cvx.installed_solvers()
# Out:
# ['ECOS', 'ECOS_BB', 'CVXOPT', 'GLPK', 'GLPK_MI', 'SCS', 'MOSEK', 'LS']

# %%
# Resolviendo el programa convexo: (toma mucho tiempo)
problem.solve(solver='CVXOPT')
# Out:
# 1.8639637145895938

# %%
# Visualizando la solución:
print("Optimal value:", problem.value)
print("Optimal C:",C.value.shape)
# Out:
# Optimal value: 1.8639637145895938
# Optimal C: (50, 50)

# %%
C=C.value #Conversión a matriz

# %%
C.shape
# Out:
# (50, 50)

# %%
# W=|C|+|C|^t
W=abs(C)+abs(C.T)
# Dii=sum{j}Wij
D=np.diag(np.apply_along_axis(np.sum,1,W))
M=D-W

# %%
# Eigendecomposition:
_,e=np.linalg.eig(M)
e=e[:,0:k]
e.shape # Ahora tiene "N" filas y "k" columnas
# Out:
# (50, 10)

# %%
# Soft assignment inicial con KMeans:
from sklearn.cluster import KMeans
groups=KMeans(k).fit(e)
labels=groups.labels_
labels.shape # Vector categórico de "N" filas
# Out:
# (50,)

# %%
# One-hot encoding de los labels:
one_hot_labels=np.array(pd.get_dummies(labels))
one_hot_labels.shape # N x k
# Out:
# (50, 10)

# %% [markdown]
# La matriz mostrada arriba contiene los *eigenvectors*. Las filas representan embeddings que caracterizan
# a cada registro de ***X***.
